# %%
import pandas as pd

# %%
matches= pd.read_csv("match_data_expanded.csv", index_col=0)

# %%
matches.shape
# Out:
# (1224, 24)

# %%
matches["Team"].value_counts()
# Out:
# Team
# Bayern Munich          68
# Leverkusen             68
# Eintracht Frankfurt    68
# Dortmund               68
# Freiburg               68
# Mainz 05               68
# RB Leipzig             68
# Werder Bremen          68
# Stuttgart              68
# Monchengladbach        68
# Wolfsburg              68
# Augsburg               68
# Union Berlin           68
# Hoffenheim             68
# Heidenheim             68
# Bochum                 68
# St. Pauli              34
# Holstein Kiel          34
# Koln                   34
# Darmstadt              34
# Name: count, dtype: int64

# %%
matches["Round"].value_counts()
# Out:
# Round
# Matchweek 1     36
# Matchweek 2     36
# Matchweek 3     36
# Matchweek 4     36
# Matchweek 5     36
# Matchweek 6     36
# Matchweek 7     36
# Matchweek 8     36
# Matchweek 9     36
# Matchweek 10    36
# Matchweek 11    36
# Matchweek 12    36
# Matchweek 13    36
# Matchweek 14    36
# Matchweek 15    36
# Matchweek 16    36
# Matchweek 17    36
# Matchweek 18    36
# Matchweek 19    36
# Matchweek 20    36
# Matchweek 21    36
# Matchweek 22    36
# Matchweek 23    36
# Matchweek 24    36
# Matchweek 25    36
# Matchweek 26    36
# Matchweek 27    36
# Matchweek 28    36
# Matchweek 29    36
# Matchweek 30    36
# Matchweek 31    36
# Matchweek 32    36
# Matchweek 33    36
# Matchweek 34    36
# Name: count, dtype: int64

# %%
matches["Date"]=pd.to_datetime(matches["Date"])
# Out:
# /var/folders/zz/tz7yr7rs1cl2y022b2vb_0640000gn/T/ipykernel_82794/1212876718.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   matches["Date"]=pd.to_datetime(matches["Date"])

# %%
matches.dtypes
# Out:
# Date          datetime64[ns]
# Time                  object
# Round                 object
# Day                   object
# Venue                 object
# Result                object
# GF                     int64
# GA                     int64
# Opponent              object
# xG                   float64
# xGA                  float64
# Poss                   int64
# Attendance            object
# Captain               object
# Formation             object
# Referee               object
# Sh                     int64
# SoT                    int64
# Dist                 float64
# FK                     int64
# PK                     int64
# PKatt                  int64
# Season                 int64
# Team                  object
# dtype: object

# %%
matches["Venue_code"]=matches["Venue"].astype("category").cat.codes

# %%
matches["Opp_code"]=matches["Opponent"].astype("category").cat.codes

# %%
matches
# Out:
#            Date           Time         Round  Day Venue Result  GF  GA  \
# 1    2024-08-25  15:30 (19:00)   Matchweek 1  Sun  Away      W   3   2
# 2    2024-09-01  17:30 (21:00)   Matchweek 2  Sun  Home      W   2   0
# 3    2024-09-14  18:30 (22:00)   Matchweek 3  Sat  Away      W   6   1
# 4    2024-09-21  15:30 (19:00)   Matchweek 4  Sat  Away      W   5   0
# 5    2024-09-28  18:30 (22:00)   Matchweek 5  Sat  Home      D   1   1
# ...         ...            ...           ...  ...   ...    ...  ..  ..
# 1220 2024-04-20  15:30 (19:00)  Matchweek 30  Sat  Away      W   2   0
# 1221 2024-04-28  19:30 (23:00)  Matchweek 31  Sun  Home      L   0   1
# 1222 2024-05-04  15:30 (19:00)  Matchweek 32  Sat  Away      L   0   3
# 1223 2024-05-12  15:30 (19:00)  Matchweek 33  Sun  Home      L   0   6
# 1224 2024-05-18  15:30 (19:00)  Matchweek 34  Sat  Away      L   0   4
#
#            Opponent   xG  ...  Sh  SoT  Dist FK PK PKatt  Season  \
# 1         Wolfsburg  2.4  ...  15    8  11.1  0  0     0    2024
# 2          Freiburg  1.5  ...  11    2  16.0  0  1     1    2024
# 3     Holstein Kiel  3.2  ...  22   11  15.9  0  1     1    2024
# 4     Werder Bremen  3.0  ...  25    7  17.3  1  0     0    2024
# 5        Leverkusen  1.4  ...  18    3  19.3  1  0     0    2024
# ...             ...  ...  ...  ..  ...   ... .. ..   ...     ...
# 1220           Köln  1.8  ...  12    6  19.9  0  0     0    2023
# 1221     Heidenheim  0.7  ...  11    3  20.2  1  0     0    2023
# 1222      Wolfsburg  0.4  ...   6    1  19.6  1  0     0    2023
# 1223     Hoffenheim  0.6  ...  10    0  19.7  0  0     0    2023
# 1224       Dortmund  0.3  ...   6    0  17.3  0  0     0    2023
#
#                Team  Venue_code  Opp_code
# 1     Bayern Munich           0        19
# 2     Bayern Munich           1         6
# 3     Bayern Munich           0        10
# 4     Bayern Munich           0        18
# 5     Bayern Munich           1        12
# ...             ...         ...       ...
# 1220      Darmstadt           0        11
# 1221      Darmstadt           1         8
# 1222      Darmstadt           0        19
# 1223      Darmstadt           1         9
# 1224      Darmstadt           0         4
#
# [1224 rows x 26 columns]

# %%
matches["hour"]=matches["Time"].str.replace(":.+","",regex=True).astype("int")

# %%
matches["day_code"] = matches["Date"].dt.day_of_week

# %%
matches["target"]=(matches["Result"]=="W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train= matches[matches["Date"]<"2025-01-01"]

# %%
test=matches[matches["Date"]>"2025-01-01"]

# %%
predictors=["Venue_code","Opp_code","hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds=rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc= accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5877192982456141

# %%
combined= pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined['actual'], columns= combined ['prediction'])
# Out:
# prediction    0   1
# actual
# 0           158  60
# 1            81  43

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4174757281553398

# %%
grouped_matches= matches.groupby("Team")

# %%
group = grouped_matches.get_group("Bayern Munich")

# %%
group
# Out:
#           Date           Time         Round  Day Venue Result  GF  GA  \
# 1   2024-08-25  15:30 (19:00)   Matchweek 1  Sun  Away      W   3   2
# 2   2024-09-01  17:30 (21:00)   Matchweek 2  Sun  Home      W   2   0
# 3   2024-09-14  18:30 (22:00)   Matchweek 3  Sat  Away      W   6   1
# 4   2024-09-21  15:30 (19:00)   Matchweek 4  Sat  Away      W   5   0
# 5   2024-09-28  18:30 (22:00)   Matchweek 5  Sat  Home      D   1   1
# ..         ...            ...           ...  ...   ...    ...  ..  ..
# 710 2024-04-20  18:30 (22:00)  Matchweek 30  Sat  Away      W   5   1
# 711 2024-04-27  15:30 (19:00)  Matchweek 31  Sat  Home      W   2   1
# 712 2024-05-04  15:30 (19:00)  Matchweek 32  Sat  Away      L   1   3
# 713 2024-05-12  17:30 (21:00)  Matchweek 33  Sun  Home      W   2   0
# 714 2024-05-18  15:30 (19:00)  Matchweek 34  Sat  Away      L   2   4
#
#            Opponent   xG  ...  FK  PK PKatt Season           Team Venue_code  \
# 1         Wolfsburg  2.4  ...   0   0     0   2024  Bayern Munich          0
# 2          Freiburg  1.5  ...   0   1     1   2024  Bayern Munich          1
# 3     Holstein Kiel  3.2  ...   0   1     1   2024  Bayern Munich          0
# 4     Werder Bremen  3.0  ...   1   0     0   2024  Bayern Munich          0
# 5        Leverkusen  1.4  ...   1   0     0   2024  Bayern Munich          1
# ..              ...  ...  ...  ..  ..   ...    ...            ...        ...
# 710    Union Berlin  1.4  ...   1   0     0   2023  Bayern Munich          0
# 711  Eint Frankfurt  3.3  ...   0   1     1   2023  Bayern Munich          1
# 712       Stuttgart  1.7  ...   0   1     1   2023  Bayern Munich          0
# 713       Wolfsburg  0.3  ...   1   0     0   2023  Bayern Munich          1
# 714      Hoffenheim  1.5  ...   1   0     0   2023  Bayern Munich          0
#
#      Opp_code  hour  day_code  target
# 1          19    15         6       1
# 2           6    17         6       1
# 3          10    18         5       1
# 4          18    15         5       1
# 5          12    18         5       0
# ..        ...   ...       ...     ...
# 710        17    18         5       1
# 711         5    15         5       1
# 712        16    15         5       0
# 713        19    17         6       1
# 714         9    15         5       0
#
# [68 rows x 29 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group=group.sort_values("Date")
    rolling_stats= group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset= new_cols)
    return group

# %%
cols= ["GF","GA","Sh","SoT","Dist","FK","PK", "PKatt"]
new_cols= [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#           Date           Time         Round  Day Venue Result  GF  GA  \
# 684 2023-09-15  20:30 (00:00)   Matchweek 4  Fri  Home      D   2   2
# 685 2023-09-23  15:30 (19:00)   Matchweek 5  Sat  Home      W   7   0
# 686 2023-09-30  18:30 (22:00)   Matchweek 6  Sat  Away      D   2   2
# 687 2023-10-08  17:30 (21:00)   Matchweek 7  Sun  Home      W   3   0
# 688 2023-10-21  18:30 (22:00)   Matchweek 8  Sat  Away      W   3   1
# ..         ...            ...           ...  ...   ...    ...  ..  ..
# 30  2025-04-19  15:30 (19:00)  Matchweek 30  Sat  Away      W   4   0
# 31  2025-04-26  15:30 (19:00)  Matchweek 31  Sat  Home      W   3   0
# 32  2025-05-03  15:30 (19:00)  Matchweek 32  Sat  Away      D   3   3
# 33  2025-05-10  18:30 (22:00)  Matchweek 33  Sat  Home      W   2   0
# 34  2025-05-17  15:30 (19:00)  Matchweek 34  Sat  Away      W   4   0
#
#        Opponent   xG  ...  day_code  target GF_rolling GA_rolling Sh_rolling  \
# 684  Leverkusen  2.1  ...         4       0   3.000000   0.666667  22.666667
# 685      Bochum  4.8  ...         5       1   2.333333   1.333333  19.666667
# 686  RB Leipzig  2.3  ...         5       0   3.666667   1.000000  22.000000
# 687    Freiburg  2.4  ...         6       1   3.666667   1.333333  17.000000
# 688    Mainz 05  1.8  ...         5       1   4.000000   0.666667  18.666667
# ..          ...  ...  ...       ...     ...        ...        ...        ...
# 30   Heidenheim  3.2  ...         5       1   2.666667   1.666667  22.000000
# 31     Mainz 05  1.1  ...         5       1   3.000000   1.000000  21.666667
# 32   RB Leipzig  1.6  ...         5       0   3.000000   0.666667  20.000000
# 33     Gladbach  2.5  ...         5       1   3.333333   1.000000  17.333333
# 34   Hoffenheim  1.4  ...         5       1   2.666667   1.000000  19.333333
#
#     SoT_rolling  Dist_rolling  FK_rolling  PK_rolling  PKatt_rolling
# 684    7.000000     17.700000    0.333333    0.333333       0.333333
# 685    6.666667     15.700000    0.000000    0.333333       0.333333
# 686   10.000000     14.266667    0.000000    0.333333       0.333333
# 687    9.000000     16.300000    0.333333    0.666667       0.666667
# 688    8.000000     17.833333    0.333333    0.666667       0.666667
# ..          ...           ...         ...         ...            ...
# 30     8.666667     15.966667    0.666667    0.000000       0.000000
# 31     9.666667     16.600000    1.000000    0.000000       0.000000
# 32     9.333333     16.466667    0.333333    0.000000       0.000000
# 33     7.666667     16.066667    0.333333    0.000000       0.000000
# 34     7.000000     16.900000    0.000000    0.000000       0.000000
#
# [65 rows x 37 columns]

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/zz/tz7yr7rs1cl2y022b2vb_0640000gn/T/ipykernel_82794/578198639.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel("Team")

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            Date           Time         Round  Day Venue Result  GF  GA  \
# 0    2023-09-16  15:30 (19:00)   Matchweek 4  Sat  Away      L   0   3
# 1    2023-09-23  15:30 (19:00)   Matchweek 5  Sat  Home      W   2   1
# 2    2023-10-01  17:30 (21:00)   Matchweek 6  Sun  Away      L   0   2
# 3    2023-10-07  15:30 (19:00)   Matchweek 7  Sat  Home      L   1   2
# 4    2023-10-22  17:30 (21:00)   Matchweek 8  Sun  Away      W   5   2
# ...         ...            ...           ...  ...   ...    ...  ..  ..
# 1156 2025-04-19  15:30 (19:00)  Matchweek 30  Sat  Away      D   2   2
# 1157 2025-04-26  15:30 (19:00)  Matchweek 31  Sat  Home      L   0   1
# 1158 2025-05-03  18:30 (22:00)  Matchweek 32  Sat  Away      L   0   4
# 1159 2025-05-09  20:30 (00:00)  Matchweek 33  Fri  Home      D   2   2
# 1160 2025-05-17  15:30 (19:00)  Matchweek 34  Sat  Away      W   1   0
#
#           Opponent   xG  ...  day_code  target GF_rolling GA_rolling  \
# 0       RB Leipzig  1.7  ...         5       0   2.333333   3.000000
# 1         Mainz 05  0.8  ...         5       1   1.000000   2.666667
# 2         Freiburg  0.8  ...         6       0   1.333333   2.000000
# 3     Darmstadt 98  0.9  ...         5       0   0.666667   2.000000
# 4       Heidenheim  2.5  ...         6       1   1.000000   1.666667
# ...            ...  ...  ...       ...     ...        ...        ...
# 1156      Mainz 05  1.6  ...         5       0   0.666667   1.666667
# 1157      Freiburg  0.3  ...         5       0   1.333333   2.000000
# 1158      Dortmund  0.7  ...         5       0   1.333333   2.000000
# 1159    Hoffenheim  1.0  ...         4       0   0.666667   2.333333
# 1160      Gladbach  1.7  ...         5       1   0.666667   2.333333
#
#      Sh_rolling SoT_rolling  Dist_rolling  FK_rolling  PK_rolling  \
# 0     13.333333    4.000000     19.700000    0.333333    0.333333
# 1     12.333333    3.666667     18.833333    0.000000    0.000000
# 2     10.666667    4.000000     16.966667    0.000000    0.000000
# 3     11.333333    3.666667     18.266667    0.000000    0.000000
# 4     12.000000    3.000000     19.166667    0.333333    0.000000
# ...         ...         ...           ...         ...         ...
# 1156  13.333333    3.666667     14.433333    0.333333    0.000000
# 1157  15.000000    4.333333     14.400000    0.333333    0.000000
# 1158  13.333333    3.666667     17.066667    0.666667    0.000000
# 1159  11.333333    2.333333     18.100000    0.666667    0.000000
# 1160  10.666667    2.666667     17.900000    0.333333    0.000000
#
#       PKatt_rolling
# 0          0.333333
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ...             ...
# 1156       0.000000
# 1157       0.000000
# 1158       0.000000
# 1159       0.000000
# 1160       0.000000
#
# [1161 rows x 37 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["Date"]<"2025-01-01"]
    test= data[data["Date"]>"2025-01-01"]
    rf.fit(train[predictors], train["target"])
    preds= rf.predict(test[predictors])
    combined= pd.DataFrame(dict(actual=test["target"], predicted= preds), index=test.index)
    precision= precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors+ new_cols)

# %%
precision
# Out:
# 0.42105263157894735

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       Date       Team       Opponent Result
# 46         0          0 2025-01-12   Augsburg      Stuttgart      L
# 47         1          0 2025-01-15   Augsburg   Union Berlin      W
# 48         1          0 2025-01-19   Augsburg  Werder Bremen      W
# 49         1          0 2025-01-25   Augsburg     Heidenheim      W
# 50         0          0 2025-02-01   Augsburg      St. Pauli      D
# ...      ...        ...        ...        ...            ...    ...
# 1156       0          0 2025-04-19  Wolfsburg       Mainz 05      D
# 1157       0          0 2025-04-26  Wolfsburg       Freiburg      L
# 1158       0          0 2025-05-03  Wolfsburg       Dortmund      L
# 1159       0          0 2025-05-09  Wolfsburg     Hoffenheim      D
# 1160       1          0 2025-05-17  Wolfsburg       Gladbach      W
#
# [342 rows x 6 columns]

# %%
merged= combined.merge(combined, left_on=["Date", "Team"], right_on=["Date", "Opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       Date     Team_x     Opponent_x Result_x  \
# 0           0            0 2025-01-12   Augsburg      Stuttgart        L
# 1           1            0 2025-01-15   Augsburg   Union Berlin        W
# 2           1            0 2025-01-19   Augsburg  Werder Bremen        W
# 3           1            0 2025-01-25   Augsburg     Heidenheim        W
# 4           0            0 2025-02-01   Augsburg      St. Pauli        D
# ..        ...          ...        ...        ...            ...      ...
# 299         0            0 2025-04-19  Wolfsburg       Mainz 05        D
# 300         0            0 2025-04-26  Wolfsburg       Freiburg        L
# 301         0            0 2025-05-03  Wolfsburg       Dortmund        L
# 302         0            0 2025-05-09  Wolfsburg     Hoffenheim        D
# 303         1            0 2025-05-17  Wolfsburg       Gladbach        W
#
#      actual_y  predicted_y           Team_y Opponent_y Result_y
# 0           1            0        Stuttgart   Augsburg        W
# 1           0            0     Union Berlin   Augsburg        L
# 2           0            0    Werder Bremen   Augsburg        L
# 3           0            0       Heidenheim   Augsburg        L
# 4           0            0        St. Pauli   Augsburg        D
# ..        ...          ...              ...        ...      ...
# 299         0            0         Mainz 05  Wolfsburg        D
# 300         1            0         Freiburg  Wolfsburg        W
# 301         1            1         Dortmund  Wolfsburg        W
# 302         0            0       Hoffenheim  Wolfsburg        D
# 303         0            1  Monchengladbach  Wolfsburg        L
#
# [304 rows x 11 columns]

# %%
merged[(merged["predicted_x"]==1) & (merged["predicted_y"]==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    24
# 1    23
# Name: count, dtype: int64

# %%
23/24
# Out:
# 0.9583333333333334
